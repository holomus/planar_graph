# %%
import pandas as pd

# %%
file_path = './tracks.csv'

# %%
df = pd.read_csv(file_path, header=1)

# %%
df
# Out:
#                                       Ф.И.О  Должность  Событие     Время
# 0   ERGASHEV MUHAMMAD SHUKUR DILSHOD O'G'LI   Продавец   Приход  07:00:22  \
# 1           ALIYEV SARDORJON SHAVKAT O'G'LI     Кассир   Приход  07:59:51
# 2           QORABOYEVA GULNORAXON MUMINOVNA  Техничка    Приход  15:24:50
# 3         G'ANIYEV ALISHER RUSTAMJON O'G'LI   Продавец   Приход  15:42:00
# 4         G'ANIYEV ALISHER RUSTAMJON O'G'LI   Продавец     Уход  23:05:36
# 5   ERGASHEV MUHAMMAD SHUKUR DILSHOD O'G'LI   Продавец     Уход  23:07:54
# 6           QORABOYEVA GULNORAXON MUMINOVNA  Техничка      Уход  23:09:23
# 7           ALIYEV SARDORJON SHAVKAT O'G'LI     Кассир     Уход  23:20:27
# 8                          Дата: 21.12.2023        NaN      NaN       NaN
# 9                                     Ф.И.О  Должность  Событие     Время
# 10             NAZAROVA SEVARA ALISHER QIZI   Продавец   Приход  06:34:41
#
#     Локации  Адрес  Описание       Дата   VALID_ROW
# 0   Авайхон      -       NaN  20.12.2023       True
# 1   Авайхон      -       NaN  20.12.2023       True
# 2   Авайхон      -       NaN  20.12.2023       True
# 3   Авайхон      -       NaN  20.12.2023       True
# 4   Авайхон      -       NaN  20.12.2023       True
# 5   Авайхон      -       NaN  20.12.2023       True
# 6   Авайхон      -       NaN  20.12.2023       True
# 7   Авайхон      -       NaN  20.12.2023       True
# 8       NaN    NaN       NaN  20.12.2023      False
# 9   Локации  Адрес  Описание  20.12.2023      False
# 10  Авайхон      -       NaN  21.12.2023       True

# %%
df = df[df['VALID_ROW'] == True]

# %%
df
# Out:
#                                       Ф.И.О  Должность Событие     Время
# 0   ERGASHEV MUHAMMAD SHUKUR DILSHOD O'G'LI   Продавец  Приход  07:00:22  \
# 1           ALIYEV SARDORJON SHAVKAT O'G'LI     Кассир  Приход  07:59:51
# 2           QORABOYEVA GULNORAXON MUMINOVNA  Техничка   Приход  15:24:50
# 3         G'ANIYEV ALISHER RUSTAMJON O'G'LI   Продавец  Приход  15:42:00
# 4         G'ANIYEV ALISHER RUSTAMJON O'G'LI   Продавец    Уход  23:05:36
# 5   ERGASHEV MUHAMMAD SHUKUR DILSHOD O'G'LI   Продавец    Уход  23:07:54
# 6           QORABOYEVA GULNORAXON MUMINOVNA  Техничка     Уход  23:09:23
# 7           ALIYEV SARDORJON SHAVKAT O'G'LI     Кассир    Уход  23:20:27
# 10             NAZAROVA SEVARA ALISHER QIZI   Продавец  Приход  06:34:41
#
#     Локации Адрес Описание       Дата   VALID_ROW
# 0   Авайхон     -      NaN  20.12.2023       True
# 1   Авайхон     -      NaN  20.12.2023       True
# 2   Авайхон     -      NaN  20.12.2023       True
# 3   Авайхон     -      NaN  20.12.2023       True
# 4   Авайхон     -      NaN  20.12.2023       True
# 5   Авайхон     -      NaN  20.12.2023       True
# 6   Авайхон     -      NaN  20.12.2023       True
# 7   Авайхон     -      NaN  20.12.2023       True
# 10  Авайхон     -      NaN  21.12.2023       True

# %%
df.to_csv('tracks_filtered.csv', index=False)
